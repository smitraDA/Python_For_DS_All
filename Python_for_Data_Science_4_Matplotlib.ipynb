# %% [markdown]
# ## Python for Data Science:4 Matplotlib

# %%
# %matplotlib inline #to get output plot here
import matplotlib.pyplot as plt #importing matplot lib library
import numpy as np 
x = range(100) 
print (x) # print and check what is x
y =[val**2 for val in x] 
print (y) 
plt.plot(x,y) #plotting x and y
# Out:
# range(0, 100)
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801]

# %%
#See how [np.linspace](http://docs.scipy.org/doc/numpy/reference/generated/numpy.linspace.html) works.
x = np.linspace(0, 2*np.pi, 100) # (start point,end point,number of samples to be created)
y =np.sin(x)
plt.plot(x,y)

# %%
x= np.linspace(-3,2, 200)
Y = x ** 2 - 2 * x + 1.
plt.plot(x,Y)

# %%
# plotting multiple plots
x =np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y) 
plt.plot(x,z)
plt.show()

# %% [markdown]
# #Scatterplot

# %%
sct = np.random.rand(20, 2) #20 row 2 colum
print (sct)
plt.scatter(sct[:,0], sct[:,1]) # I am plotting a scatter plot.all row 0 colum, all row 1st colum
# Out:
# [[0.5483134  0.66667036]
#  [0.99783158 0.8640023 ]
#  [0.80981616 0.65637676]
#  [0.98519921 0.21963095]
#  [0.94143756 0.00871354]
#  [0.25432475 0.63331639]
#  [0.96886825 0.18036348]
#  [0.78326857 0.36701526]
#  [0.10140685 0.16733587]
#  [0.33246407 0.42872919]
#  [0.36149147 0.51589033]
#  [0.34133814 0.74076155]
#  [0.8825861  0.79585891]
#  [0.38104445 0.31855862]
#  [0.74720928 0.66344009]
#  [0.09575275 0.39253741]
#  [0.26358504 0.85135509]
#  [0.54724951 0.21213812]
#  [0.85748206 0.02050741]
#  [0.32949785 0.4293323 ]]

# %% [markdown]
# #Bar

# %%
ghj =[5, 10 ,15, 20, 25]
it =[ 1, 2, 3, 4, 5]
plt.bar(ghj, it) # simple bar graph
# Out:
# <BarContainer object of 5 artists>

# %%
ghj =[5, 10 ,15, 20, 25]
it =[ 1, 2, 3, 4, 5]
plt.bar(ghj, it, width =5)# you can change the thickness of a bar, by default the bar will have a thickness of 0.8 units
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# #Pie charts

# %%
y = [5, 25, 45, 65]
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x2708a344e10>,
#   <matplotlib.patches.Wedge at 0x2708a34c320>,
#   <matplotlib.patches.Wedge at 0x2708a34c7f0>,
#   <matplotlib.patches.Wedge at 0x2708a34ccc0>],
#  [Text(1.0930834302648262, 0.12316092919623813, ''),
#   Text(0.7778174410990706, 0.7778174775113337, ''),
#   Text(-0.7778174775113338, 0.7778174410990705, ''),
#   Text(0.12316089081804174, -1.09308343458901, '')])

# %% [markdown]
# #Histogram

# %%
d = np.random.randn(100)
plt.hist(d, bins = 20)
# Out:
# (array([ 3.,  2.,  2.,  3.,  4.,  1.,  9., 10., 10., 11., 13.,  5., 11.,
#          5.,  3.,  3.,  3.,  0.,  1.,  1.]),
#  array([-2.36329037, -2.11544242, -1.86759447, -1.61974652, -1.37189857,
#         -1.12405062, -0.87620267, -0.62835472, -0.38050677, -0.13265882,
#          0.11518913,  0.36303708,  0.61088503,  0.85873298,  1.10658093,
#          1.35442888,  1.60227683,  1.85012478,  2.09797273,  2.34582068,
#          2.59366863]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# #Boxplot

# %%
d = np.random.randn(100)
plt.boxplot(d)
#1) The red bar is the median of the distribution
#2) The blue box includes 50 percent of the data from the lower quartile to the upper quartile. 
#   Thus, the box is centered on the median of the data.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2708a411ba8>,
#   <matplotlib.lines.Line2D at 0x2708a411ef0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2708a411fd0>,
#   <matplotlib.lines.Line2D at 0x2708a41d5c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2708a411780>],
#  'medians': [<matplotlib.lines.Line2D at 0x2708a41d908>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2708a41dc50>],
#  'means': []}

# %%
d = np.random.randn(100, 5) # generating multiple box plots
plt.boxplot(d)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2708a466f28>,
#   <matplotlib.lines.Line2D at 0x2708a472588>,
#   <matplotlib.lines.Line2D at 0x2708a47a978>,
#   <matplotlib.lines.Line2D at 0x2708a47acc0>,
#   <matplotlib.lines.Line2D at 0x2708a485e48>,
#   <matplotlib.lines.Line2D at 0x2708a48e438>,
#   <matplotlib.lines.Line2D at 0x2708a499828>,
#   <matplotlib.lines.Line2D at 0x2708a499b70>,
#   <matplotlib.lines.Line2D at 0x2708a4a3f60>,
#   <matplotlib.lines.Line2D at 0x2708a4ad2e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2708a4728d0>,
#   <matplotlib.lines.Line2D at 0x2708a472c18>,
#   <matplotlib.lines.Line2D at 0x2708a47ada0>,
#   <matplotlib.lines.Line2D at 0x2708a485390>,
#   <matplotlib.lines.Line2D at 0x2708a48e780>,
#   <matplotlib.lines.Line2D at 0x2708a48eac8>,
#   <matplotlib.lines.Line2D at 0x2708a499eb8>,
#   <matplotlib.lines.Line2D at 0x2708a499f98>,
#   <matplotlib.lines.Line2D at 0x2708a4ad630>,
#   <matplotlib.lines.Line2D at 0x2708a4ad978>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2708a466dd8>,
#   <matplotlib.lines.Line2D at 0x2708a47a630>,
#   <matplotlib.lines.Line2D at 0x2708a485d68>,
#   <matplotlib.lines.Line2D at 0x2708a4994e0>,
#   <matplotlib.lines.Line2D at 0x2708a4a3c18>],
#  'medians': [<matplotlib.lines.Line2D at 0x2708a472f60>,
#   <matplotlib.lines.Line2D at 0x2708a4856d8>,
#   <matplotlib.lines.Line2D at 0x2708a48ee10>,
#   <matplotlib.lines.Line2D at 0x2708a4a3588>,
#   <matplotlib.lines.Line2D at 0x2708a4adcc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2708a47a2e8>,
#   <matplotlib.lines.Line2D at 0x2708a485a20>,
#   <matplotlib.lines.Line2D at 0x2708a48eef0>,
#   <matplotlib.lines.Line2D at 0x2708a4a38d0>,
#   <matplotlib.lines.Line2D at 0x2708a4adda0>],
#  'means': []}
